# %%
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
import argparse

import torch
import numpy as np
from tabpfn_extensions.embedding import TabPFNEmbedding


import warnings
warnings.filterwarnings("ignore")

# %%
def tsne_plot(features,property_values,num_levels, name):
    print("Data loaded successfully.")
    print(f"Shape of the feature data: {features.shape}")
    # Step 2: Initialize and run the t-SNE algorithm.
    print("\nStarting t-SNE dimensionality reduction...")
    tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=1000, random_state=42)
    tsne_results = tsne.fit_transform(features)
    print("t-SNE calculation complete.")
    # Step 3: Create DataFrame and discretize property values for coloring.
    df_tsne = pd.DataFrame(data=tsne_results, columns=['tsne_dim_1', 'tsne_dim_2'])
    df_tsne['property'] = property_values

    # Bin the continuous property values into discrete levels.
    # `pd.cut` creates bins of equal width from the range of property values.

    #df_tsne['property_level'] = pd.cut(df_tsne['property'], bins=num_levels, labels=False)
    df_tsne['property_level'] = pd.qcut(df_tsne['property'], q=num_levels, labels=False, duplicates='drop')


    # Step 4: Visualize the results.
    print("Generating plot...")
    plt.style.use('seaborn-v0_8-whitegrid')
    plt.figure(figsize=(14, 12))
    scatter_plot = sns.scatterplot(
        x="tsne_dim_1", y="tsne_dim_2",
        hue="property_level",  # Color points by the discrete property level
        palette=sns.color_palette("viridis", n_colors=num_levels), # Use a discrete colormap
        data=df_tsne,
        alpha=0.7,
        s=50,
        legend='full' # Ensure the legend is shown correctly for discrete values
    )
    plt.title(f't-SNE Visualization ({num_levels} Property Levels)', fontsize=18)
    plt.xlabel('t-SNE Dimension 1', fontsize=12)
    plt.ylabel('t-SNE Dimension 2', fontsize=12)

    # Set the legend title.
    legend = scatter_plot.get_legend()
    if legend:
        legend.set_title(f'Property Level')
    plt.grid(True)

    # Save the plot to a file
    output_filename = f'{name}_tsne_{num_levels}_levels.png'
    plt.savefig(output_filename, dpi=300)
    print(f"\nPlot saved as '{output_filename}'")

    # Display the plot
    plt.show()

# %%
compo = "./TabPFN_4"
Farm_tab = compo+"/tabpfn_model.pt"
input_csv = "TabPFN_fold4_data/fold4_train_labeled.csv"  # adjust if needed

# %%
FMmodel = torch.load(Farm_tab)
FM_extractor = TabPFNEmbedding(tabpfn_clf=FMmodel, n_fold=0)
df_test = pd.read_csv(input_csv)

# Split features and targets
FMX = df_test.drop(columns=["target"]).values.astype(np.float32)
FMy = df_test["target"].values.astype(np.float32)

print(FMX.shape)
print(FMy.shape)
# Out:
# (2520, 152)
# (2520,)

# %%
import tabpfn_extensions
print(tabpfn_extensions.__version__)
import tabpfn
print(tabpfn.__version__)
# Out:
# 0.1.6
# 2.2.1

# %%
import os
import numpy as np
torch.cuda.empty_cache()
import gc
gc.collect()

batch_size = 256  # try 128 or 64 if memory is still tight
embeddings = []

os.environ["CUDA_VISIBLE_DEVICES"] = "2"   # or another index
torch.cuda.set_device(0)

for i in range(0, len(FMX), batch_size):
    
    X_batch = FMX[i:i + batch_size]
    with torch.no_grad():
        emb = FM_extractor.get_embeddings(
            X_batch, FMy[i:i + batch_size], X_batch, data_source="train"
        )
    embeddings.append(emb)
    torch.cuda.empty_cache()   # free unused memory between batches
    gc.collect()

FM_embeddings = np.concatenate(embeddings, axis=0)
print("FM_embeddings:", FM_embeddings.shape)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[9], line 17
#      15 X_batch = FMX[i:i + batch_size]
#      16 with torch.no_grad():
# ---> 17     emb = FM_extractor.get_embeddings(
#      18         X_batch, FMy[i:i + batch_size], X_batch, data_source="train"
#      19     )
#      20 embeddings.append(emb)
#      21 torch.cuda.empty_cache()   # free unused memory between batches
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/tabpfn_common_utils/telemetry/core/decorators.py:139, in _wrap_callable_with_extension.<locals>.wrapped(*args, **kwargs)
#     137     return fn(*args, **kwargs)
#     138 with _extension_context(extension_name):
# --> 139     return fn(*args, **kwargs)
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/tabpfn_extensions/embedding/tabpfn_embedding.py:128, in TabPFNEmbedding.get_embeddings(self, X_train, y_train, X, data_source)
#     126 if self.n_fold == 0:
#     127     self.model.fit(X_train, y_train)
# --> 128     return self.model.get_embeddings(X, data_source=data_source)
#     129 elif self.n_fold >= 2:
#     130     if data_source == "test":
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/tabpfn/regressor.py:1110, in TabPFNRegressor.get_embeddings(self, X, data_source)
#    1090 def get_embeddings(
#    1091     self,
#    1092     X: XType,
#    1093     data_source: Literal["train", "test"] = "test",
#    1094 ) -> np.ndarray:
#    1095     """Gets the embeddings for the input data `X`.
#    1096
#    1097     Args:
#    (...)
#    1108             The computed embeddings for each fitted estimator.
#    1109     """
# -> 1110     return get_embeddings(self, X, data_source)
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/tabpfn/utils.py:106, in get_embeddings(model, X, data_source)
#     103 embeddings: list[np.ndarray] = []
#     105 # Cast executor to Any to bypass the iter_outputs signature check
# --> 106 for output, config in model.executor_.iter_outputs(
#     107     X,
#     108     devices=model.devices_,
#     109     autocast=model.use_autocast_,
#     110     only_return_standard_out=False,
#     111 ):
#     112     # Cast output to Any to allow dict-like access
#     113     output_dict = typing.cast("dict[str, torch.Tensor]", output)
#     114     embed = output_dict[selected_data].squeeze(1)
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/tabpfn/inference.py:507, in InferenceEngineCachePreprocessing.iter_outputs(self, X, devices, autocast, only_return_standard_out)
#     491 model_forward_functions = (
#     492     partial(
#     493         self._call_model,
#    (...)
#     503     )
#     504 )
#     505 outputs = parallel_execute(devices, model_forward_functions)
# --> 507 for output, config in zip(outputs, self.ensemble_configs):
#     508     yield _move_and_squeeze_output(output, devices[0]), config
#     510 if self.inference_mode:
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/tabpfn/parallel_execute.py:58, in parallel_execute(devices, functions)
#      39 """Evaluate the given functions in parallel across `devices`.
#      40
#      41 The function evaluations are parallelised using Python threads, so this will only
#    (...)
#      54     as `functions`.
#      55 """
#      56 if len(devices) == 1:
#      57     # If we only have one device then just use the current thread to avoid overhead.
# ---> 58     yield from _execute_in_current_thread(devices[0], functions)
#      59 else:
#      60     yield from _execute_with_multithreading(devices, functions)
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/tabpfn/parallel_execute.py:67, in _execute_in_current_thread(device, functions)
#      63 def _execute_in_current_thread(
#      64     device: torch.device, functions: Iterable[ParallelFunction[R_co]]
#      65 ) -> Generator[R_co]:
#      66     for function in functions:
# ---> 67         yield function(device=device, is_parallel=False)
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/tabpfn/inference.py:555, in InferenceEngineCachePreprocessing._call_model(self, device, is_parallel, X_train, X_test, y_train, cat_ix, autocast, only_return_standard_out)
#     541     MemoryUsageEstimator.reset_peak_memory_if_required(
#     542         save_peak_mem=self.save_peak_mem,
#     543         model=model,
#    (...)
#     548         safety_factor=1.2,
#     549     )
#     551 with (
#     552     get_autocast_context(device, enabled=autocast),
#     553     torch.inference_mode(self.inference_mode),
#     554 ):
# --> 555     return model(
#     556         X_full,
#     557         y_train,
#     558         only_return_standard_out=only_return_standard_out,
#     559         categorical_inds=batched_cat_ix,
#     560     )
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/tabpfn/architectures/base/transformer.py:549, in PerFeatureTransformer.forward(***failed resolving arguments***)
#     541     raise ValueError(
#     542         f"There should be no NaNs in the encoded x and y."
#     543         "Check that you do not feed NaNs or use a NaN-handling enocder."
#     544         "Your embedded x and y returned the following:"
#     545         f"{torch.isnan(embedded_x).any()=} | {torch.isnan(embedded_y).any()=}",
#     546     )
#     547 del embedded_y, embedded_x
# --> 549 encoder_out = self.transformer_encoder(
#     550     (
#     551         embedded_input
#     552         if not self.transformer_decoder
#     553         else embedded_input[:, :single_eval_pos]
#     554     ),
#     555     single_eval_pos=single_eval_pos,
#     556     cache_trainset_representation=self.cache_trainset_representation,
#     557 )  # b s f+1 e -> b s f+1 e
#     559 # If we are using a decoder
#     560 if self.transformer_decoder:
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/tabpfn/architectures/base/transformer.py:94, in LayerStack.forward(self, x, **kwargs)
#      92         x = checkpoint(partial(layer, **kwargs), x, use_reentrant=False)  # type: ignore
#      93     else:
# ---> 94         x = layer(x, **kwargs)
#      96 return x
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/tabpfn/architectures/base/layer.py:421, in PerFeatureEncoderLayer.forward(self, state, single_eval_pos, cache_trainset_representation, att_src)
#     411     raise AssertionError(
#     412         "Pre-norm implementation is wrong, as the residual should never"
#     413         " be layer normed here.",
#     414     )
#     415     state = layer_norm(
#     416         state,
#     417         allow_inplace=True,
#     418         save_peak_mem_factor=save_peak_mem_factor,
#     419     )
# --> 421 state = sublayer(state)
#     422 if not self.pre_norm:
#     423     state = layer_norm(
#     424         state,
#     425         allow_inplace=True,
#     426         save_peak_mem_factor=save_peak_mem_factor,
#     427     )
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/tabpfn/architectures/base/mlp.py:132, in MLP.forward(self, x, add_input, allow_inplace, save_peak_mem_factor)
#     130 input_shape = x.shape
#     131 x = x.reshape(-1, x.size(-1))
# --> 132 x = self._compute(
#     133     x,
#     134     add_input=add_input,
#     135     allow_inplace=allow_inplace,
#     136     save_peak_mem_factor=save_peak_mem_factor,
#     137 )
#     138 return x.reshape(input_shape)
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/tabpfn/architectures/base/memory.py:101, in support_save_peak_mem_factor.<locals>.method_(self, x, add_input, allow_inplace, save_peak_mem_factor, *args, **kwargs)
#      98     return x
#     100 if add_input:
# --> 101     return x + method(self, x, *args, **kwargs)
#     103 return method(self, x, *args, **kwargs)
#
# File ~/.conda/envs/alignn/lib/python3.10/site-packages/tabpfn/architectures/base/mlp.py:97, in MLP._compute(self, x)
#      95 x = self.linear1(x)
#      96 if self.activation is Activation.GELU:
# ---> 97     x = torch.nn.functional.gelu(x)
#      98 elif self.activation is Activation.RELU:
#      99     x = torch.nn.functional.relu(x)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 1.07 GiB. GPU 0 has a total capacity of 10.75 GiB of which 507.69 MiB is free. Process 2479587 has 5.76 GiB memory in use. Process 2479625 has 1.27 GiB memory in use. Process 2479646 has 1.27 GiB memory in use. Including non-PyTorch memory, this process has 1.94 GiB memory in use. Of the allocated memory 1.68 GiB is allocated by PyTorch, and 74.36 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
