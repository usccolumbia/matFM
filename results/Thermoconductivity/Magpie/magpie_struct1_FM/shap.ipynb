# %%
from tabpfn_extensions import TabPFNClassifier, interpretability
import torch
import pandas as pd
import numpy as np
import os
# Out:
# /home/rongzhid/.conda/envs/alignn/lib/python3.10/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
